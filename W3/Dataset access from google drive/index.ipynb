# %%
print("Hello world")
# Out:
# Hello world

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
df = pd.read_csv('gdrive/My Drive/Colab Notebooks/irishdata/iris.csv')

# %%
df = pd.read_csv('gdrive/My Drive/Colab Notebooks/handonpython/iris.csv')

# %% [markdown]
# #Headline

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# prompt: Using dataframe df: histogram

import altair as alt
chart = alt.Chart(df).mark_bar().encode(x='petal_width:Q', color='variety:N', y='count()')
chart
# Out:
# alt.Chart(...)

# %%
from matplotlib import pyplot as plt
_df_0['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
plt.gca().spines[['top', 'right',]].set_visible(False)
